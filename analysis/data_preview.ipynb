# %%
import pandas as pd
import os

# %%
tsp_solution="./data/qaoa_tsp_solution_tmp"

# %%
os.chdir("..")

# %%
with open(tsp_solution) as f:
    data=f.readlines()

# %%
data=list(map(lambda x: x[1:-2]+"\n", data))

# %%
data.insert(0,", opt_param, opt_state, opt_cost, eval_cost, iteration")

# %%
with open(tsp_solution+"_new", "w") as f:
    f.writelines(data)

# %%
pd.read_csv(tsp_solution+"_new")
# Out:
#     Unnamed: 0                opt_param           opt_state  opt_cost  \
# 0            1    array([1.00000000e-01    2.85768455e-12])        [0
# 1            2    array([1.00000000e-01    6.19705198e-12])        [0
# 2            3       array([ 2.90019952       -0.00631379])        [0
# 3            4       array([ 0.04812845       -0.02501752])        []
# 4            5    array([1.00000000e-01    1.98824952e-12])        [0
# 5            6   array([-1.00000000e-01    4.68567851e-12])        [0
# 6            7       array([ 1.35             -0.30000002])        [0
# 7            8        array([2.91243875        0.04830142])        [1
# 8            9    array([1.00000000e-01    1.29831368e-12])        []
# 9           10   array([-1.00000000e-01    4.29426344e-12])        [0
# 10          11    array([1.00000000e-01    3.07632429e-12])        [0
# 11          12    array([1.00000000e-01    4.41808104e-12])        [0
# ...

# %%
str.replace?

# %%
"[2,13,3],[1]".replace("[","'[")
# Out:
# "'[2,13,3],'[1]"
